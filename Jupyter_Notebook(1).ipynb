# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio <H1>

# %% [markdown]
# **Ahmed Amine Adlani** <br>
# Actuary

# %% [markdown]
# *I'm interested in Data science because it enables to utilize big data bases and extract key informations from it. Also, Data science can be applied to a wide range of sectors which makes the work spectrum wider.*

# %% [markdown]
# <H3> My code is a function that takes as an input a chain of character and returns as an output the same chain of characters but in capital letters.<H3>

# %%
def capital(a):
    if (a.isupper()) == TRUE:
        print(a)
    else:
        print(a.upper())

# %% [markdown]
#  ( ) This is a bullet list <br> <s> strikethrough </s> <br> [Project_URL](https://labs.cognitiveclass.ai/tools/jupyterlab/lab/tree/labs/DS0105EN/Jupyter_Notebook.ipynb?lti=true)
